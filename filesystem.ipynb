# %%
import os

# %%
os.makedirs('./Lone_Data')

# %%
os.listdir('./Lone_Data/')
# Out:
# []

# %%
url1 = 'https://gist.githubusercontent.com/aakashns/257f6e6c8719c17d0e498ea287d1a386/raw/7def9ef4234ddf0bc82f855ad67dac8b971852ef/loans1.txt'
url2 = 'https://gist.githubusercontent.com/aakashns/257f6e6c8719c17d0e498ea287d1a386/raw/7def9ef4234ddf0bc82f855ad67dac8b971852ef/loans2.txt'
url3 = 'https://gist.githubusercontent.com/aakashns/257f6e6c8719c17d0e498ea287d1a386/raw/7def9ef4234ddf0bc82f855ad67dac8b971852ef/loans3.txt'

# %%
import requests

url = 'https://leetcode.com/swapnili019/'  # Replace this with the actual URL you want to access
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    print('Request was successful')
    print(response.text)
else:
    print('Request failed with status code', response)
# Out:
# Request was successful
# ...

# %%
from bs4 import BeautifulSoup
import requests

url = "https://leetcode.com/vishal2003/"  # Replace with the actual URL of the page
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# Find all image tags
images = soup.find_all('img')

# Extract the image URLs
image_urls = [img['src'] for img in images]

# Print the image URLs
for image_url in image_urls:
    print(image_url)
# Out:
# https://assets.leetcode.com/users/avatars/avatar_1664000582.png
# https://assets.leetcode.com/static_assets/marketing/lg50.png
# https://assets.leetcode.com/static_assets/marketing/lg2023.png
# https://assets.leetcode.com/static_assets/marketing/lg100.png
# /_next/static/images/null_light-53585615fd723ba992bd2df7a10d10d1.png
# /_next/static/images/us-4787d154ddfcd171038dd5c1c98f7f07.svg

# %%
from urllib.request import urlretrieve

# %%
urlretrieve(url1, './Lone_Data/lone1.txt')
# Out:
# ('./Lone_Data/lone1.txt', <http.client.HTTPMessage at 0x1a3b33e25d0>)

# %%
urlretrieve(url2, './Lone_Data/lone2.txt')
# Out:
# ('./Lone_Data/lone2.txt', <http.client.HTTPMessage at 0x1a3b30a0a10>)

# %%
urlretrieve(url3, './Lone_Data/lone3.txt')
# Out:
# ('./Lone_Data/lone3.txt', <http.client.HTTPMessage at 0x1a3b316a890>)

# %%
os.listdir('./Lone_Data/')
# Out:
# ['lone1.txt', 'lone2.txt', 'lone3.txt']

# %%
file1 = open('./Lone_Data/lone1.txt', mode='r')

# %%
file1Content = file1.read()

# %%
print(file1Content)
# Out:
# amount,duration,rate,down_payment
# 100000,36,0.08,20000
# 200000,12,0.1,
# 628400,120,0.12,100000
# 4637400,240,0.06,
# 42900,90,0.07,8900
# 916000,16,0.13,
# 45230,48,0.08,4300
# 991360,99,0.08,
# 423000,27,0.09,47200

# %%
with open('./Lone_Data/lone1.txt', 'r') as file3:
    file3_lines = file3.readlines()

# %%
file3_lines
# Out:
# ['amount,duration,rate,down_payment\n',
#  '100000,36,0.08,20000\n',
#  '200000,12,0.1,\n',
#  '628400,120,0.12,100000\n',
#  '4637400,240,0.06,\n',
#  '42900,90,0.07,8900\n',
#  '916000,16,0.13,\n',
#  '45230,48,0.08,4300\n',
#  '991360,99,0.08,\n',
#  '423000,27,0.09,47200']

# %%
def parse_headers(header_line):
    return header_line.strip().split(',')

# %%
headers = parse_headers(file3_lines[0])

# %%
headers
# Out:
# ['amount', 'duration', 'rate', 'down_payment']
